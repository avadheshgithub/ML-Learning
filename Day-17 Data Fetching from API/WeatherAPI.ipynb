# %%
import requests
import pandas as pd

url = "https://weatherbit-v1-mashape.p.rapidapi.com/forecast/3hourly"

querystring = {"lat":"35.5","lon":"-78.5","units":"imperial","lang":"en"}

headers = {
	"x-rapidapi-key": "7a87c0226fmsh9fa743a2e63714dp160b19jsn2357b87ce444",
	"x-rapidapi-host": "weatherbit-v1-mashape.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'timezone': 'America/New_York', 'data': [{'snow_depth': 0, 'dni': 0, 'pop': 65, 'ozone': 280, 'clouds_hi': 100, 'clouds_low': 100, 'clouds_mid': 0, 'pod': 'n', 'pres': 1003, 'clouds': 92, 'vis': 0, 'wind_spd': 9.8, 'wind_cdir_full': 'south', 'slp': 1011, 'datetime': '2025-02-16:06', 'ts': 1739685600, 'timestamp_local': '2025-02-16T01:00:00', 'dewpt': 57.2, 'uv': 0, 'wind_gust_spd': 18.6, 'ghi': 0, 'dhi': 0, 'precip': 0.05, 'weather': {'description': 'Light shower rain', 'icon': 'r04n', 'code': 520}, 'rh': 100, 'temp': 57.2, 'solar_rad': 0, 'app_temp': 57.2, 'wind_dir': 180, 'timestamp_utc': '2025-02-16T06:00:00', 'snow': 0, 'wind_cdir': 'S'}, {'snow_depth': 0, 'dni': 0, 'pop': 25, 'ozone': 280, 'clouds_hi': 100, 'clouds_low': 100, 'clouds_mid': 0, 'pod': 'n', 'pres': 1000, 'clouds': 94, 'vis': 0.1, 'wind_spd': 14.3, 'wind_cdir_full': 'south-southwest', 'slp': 1008, 'datetime': '2025-02-16:09', 'ts': 1739696400, 'timestamp_local': '2025-02-16T04:00:00', 'dewpt': 61.7, 'uv': 0, 'wind_
# ...

# %%
temp_df = pd.DataFrame(response.json()['data'])

# %%
import pandas as pd

# Load JSON response
response_json = response.json()

# Extract the "data" list (which contains all the records)
weather_data = response_json.get("data", [])

# Convert list of dictionaries to DataFrame
df = pd.DataFrame(weather_data)

# Save DataFrame to CSV
df.to_csv("api_weather_data.csv", index=False)

print("✅ API data saved successfully to 'api_weather_data.csv'")
# Out:
# ✅ API data saved successfully to 'api_weather_data.csv'

# %%
temp_df.head()
# Out:
#    snow_depth  dni  pop  ozone  clouds_hi  clouds_low  clouds_mid pod  pres  \
# 0         0.0    0   65    280        100         100           0   n  1003
# 1         0.0    0   25    280        100         100           0   n  1000
# 2         0.0    0   25    279        100          17          87   n   997
# 3         0.0  808   40    285        100         100         100   d   993
# 4         0.0  881   70    297        100           1         100   d   990
#
#    clouds  ...  precip                                            weather  \
# 0      92  ...    0.05  {'description': 'Light shower rain', 'icon': '...
# 1      94  ...    0.01  {'description': 'Overcast clouds', 'icon': 'c0...
# 2      91  ...    0.01  {'description': 'Overcast clouds', 'icon': 'c0...
# 3      92  ...    0.02  {'description': 'Overcast clouds', 'icon': 'c0...
# 4      92  ...    0.07  {'description': 'Light shower rain', 'icon': '...
#
# ...

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(0, 40):
    response = requests.get(url, headers=headers, params=querystring)
    
    # Extract data from JSON response
    temp_df = pd.DataFrame(response.json().get('data', []))

    # Use pd.concat instead of append
    df = pd.concat([df, temp_df], ignore_index=True)

# Display the first few rows
print(df.head())

# %%
df.to_csv("Weather_data.csv", index=False)

# %%
temp_df.head()
# Out:
#    snow_depth  dni  pop  ozone  clouds_hi  clouds_low  clouds_mid pod  pres  \
# 0         0.0    0   65    280        100         100           0   n  1003
# 1         0.0    0   25    280        100         100           0   n  1000
# 2         0.0    0   25    279        100          17          87   n   997
# 3         0.0  808   40    285        100         100         100   d   993
# 4         0.0  881   70    297        100           1         100   d   990
#
#    clouds  ...  precip                                            weather  \
# 0      92  ...    0.05  {'description': 'Light shower rain', 'icon': '...
# 1      94  ...    0.01  {'description': 'Overcast clouds', 'icon': 'c0...
# 2      91  ...    0.01  {'description': 'Overcast clouds', 'icon': 'c0...
# 3      92  ...    0.02  {'description': 'Overcast clouds', 'icon': 'c0...
# 4      92  ...    0.07  {'description': 'Light shower rain', 'icon': '...
#
# ...

# %%
## Location wise weather Data
